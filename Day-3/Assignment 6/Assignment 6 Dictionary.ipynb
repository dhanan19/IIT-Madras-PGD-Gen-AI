# %%
university_system = {
    "universities": {
        "GTU_India": {
            "location": "Chennai",
            "ranking": 5,
            "faculties": {
                "engineering": {
                    "dean": "Dr. Narayan",
                    "departments": {
                        "computer_science": {
                            "hod": "Dr. Anish",
                            "labs": {
                                "AI Lab": {
                                    "incharge": "Dr. Meera",
                                    "research_projects": {
                                        "DeepVision": {
                                            "funding": 250000,
                                            "researchers": ["Arjun", "Sneha"],
                                            "status": "ongoing"
                                        },
                                        "RoboMind": {
                                            "funding": 180000,
                                            "researchers": ["Ishita", "Rahul"],
                                            "status": "completed"
                                        }
                                    }
                                },
                                "Systems Lab": {
                                    "incharge": "Dr. Raman",
                                    "research_projects": {
                                        "CloudScale": {
                                            "funding": 300000,
                                            "researchers": ["Karan", "Neha"],
                                            "status": "ongoing"
                                        }
                                    }
                                }
                            },
                            "courses": {
                                "Data Structures": {
                                    "credits": 4,
                                    "students_enrolled": 120
                                },
                                "Machine Learning": {
                                    "credits": 3,
                                    "students_enrolled": 90
                                }
                            }
                        }
                    }
                },
                "management": {
                    "dean": "Dr. Kapoor",
                    "departments": {
                        "finance": {
                            "hod": "Dr. Iyer",
                            "courses": {
                                "Corporate Finance": {
                                    "credits": 3,
                                    "students_enrolled": 80
                                }
                            }
                        }
                    }
                }
            }
        },
        "GTU_Singapore": {
            "location": "Singapore",
            "ranking": 2,
            "faculties": {
                "engineering": {
                    "dean": "Dr. Lee",
                    "departments": {
                        "robotics": {
                            "hod": "Dr. Tan",
                            "labs": {
                                "Automation Lab": {
                                    "incharge": "Dr. Wong",
                                    "research_projects": {
                                        "AutoNav": {
                                            "funding": 400000,
                                            "researchers": ["Jason", "Lily"],
                                            "status": "ongoing"
                                        }
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }
    }
}

# %% [raw]
# Questions to improve your understanding of dictionary
#
#
# 1.	Print the location of GTU_India.
# 2.	Print the dean of the engineering faculty in GTU_Singapore.
# 3.	Print the HOD of the computer_science department.
# 4.	Print all labs under computer_science.
# 5.	Print the funding amount of the "DeepVision" project.
# 6.	Print all research project names in GTU_India.
# 7.	Print all ongoing projects in GTU_India.
# 8.	Calculate the total funding for all projects in AI Lab.
# 9.	Print all researchers working under Systems Lab.
# 10.	Count total students enrolled in all computer_science courses.
# 11.	Print all university names in the system.
# 12.	Print all faculty names under GTU_India.
# 13.	Print all department names across all universities.
# 14.	Print all deans in the entire system.
# 15.	Print all project names across both universities.
# 16.	Add a new research project under AI Lab.
# 17.	Change the status of "DeepVision" to completed.
# 18.	Increase funding of "CloudScale" by 50,000.
# 19.	Add a new university to the system.
# 20.	Add a new course under finance department.
# 21.	Find the project with the highest funding.
# 22.	Find total funding across all universities.
# 23.	Find the university with the best ranking.
# 24.	Print all completed projects.
# 25.	Count total number of researchers in GTU_India.
# 26.	Find which lab has the maximum funding.
# 27.	Print projects grouped by status (ongoing/completed).
# 28.	Print all courses with more than 100 students enrolled.
# 29.	Find total number of faculties in the entire system.
# 30.	Write a function that searches for a project name and prints its full details.

# %%
#Q1. Print the location of GTU_India
print(university_system["universities"]["GTU_India"]["location"])
# Out:
# Chennai

# %%
#Q2. Print the dean of the engineering faculty in GTU_Singapore
print(university_system["universities"]["GTU_Singapore"]["faculties"]["engineering"]["dean"])
# Out:
# Dr. Lee

# %%
#Q3. Print the HOD of the computer_science department
print(
    university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["hod"]
)
# Out:
# Dr. Anish

# %%
#Q4. Print all labs under computer_science
labs = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]

for lab in labs:
    print(lab)
# Out:
# AI Lab
# Systems Lab

# %%
#Q5. Print the funding amount of the "DeepVision" project
print(
    university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["AI Lab"]["research_projects"]["DeepVision"]["funding"]
)
# Out:
# 250000

# %%
#Q6. Print all research project names in GTU_India
cs = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]

for lab in cs["labs"].values():
    for project in lab["research_projects"]:
        print(project)
# Out:
# DeepVision
# RoboMind
# CloudScale

# %%
#Q7. Print all ongoing projects in GTU_India
for lab in cs["labs"].values():
    for project, details in lab["research_projects"].items():
        if details["status"] == "ongoing":
            print(project)
# Out:
# DeepVision
# CloudScale

# %%
#Q8. Calculate the total funding for all projects in AI Lab
ai_projects = cs["labs"]["AI Lab"]["research_projects"]

total = sum(project["funding"] for project in ai_projects.values())

print(total)
# Out:
# 430000

# %%
#Q9. Print all researchers working under Systems Lab
systems_projects = cs["labs"]["Systems Lab"]["research_projects"]

for project in systems_projects.values():
    for researcher in project["researchers"]:
        print(researcher)
# Out:
# Karan
# Neha

# %%
#Q10. Count total students enrolled in all computer_science courses
courses = cs["courses"]

total_students = sum(course["students_enrolled"] for course in courses.values())

print(total_students)
# Out:
# 210

# %%
#Q11. Print all university names in the system
for university in university_system["universities"]:
    print(university)
# Out:
# GTU_India
# GTU_Singapore

# %%
#Q12. Print all faculty names under GTU_India
for faculty in university_system["universities"]["GTU_India"]["faculties"]:
    print(faculty)
# Out:
# engineering
# management

# %%
#Q13. Print all department names across all universities
for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"]:
            print(department)
# Out:
# computer_science
# finance
# robotics

# %%
#Q14. Print all deans in the entire system
for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        print(faculty["dean"])
# Out:
# Dr. Narayan
# Dr. Kapoor
# Dr. Lee

# %%
#Q15. Print all project names across both universities
for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            if "labs" in department:
                for lab in department["labs"].values():
                    for project in lab["research_projects"]:
                        print(project)
# Out:
# DeepVision
# RoboMind
# CloudScale
# AutoNav

# %%
#Q16. Add a new research project under AI Lab
university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["AI Lab"]["research_projects"]["SmartAI"] = {
    "funding": 220000,
    "researchers": ["Riya", "Aman"],
    "status": "ongoing"
}

# %%
#Q17. Change the status of "DeepVision" to completed
university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["AI Lab"]["research_projects"]["DeepVision"]["status"] = "completed"

# %%
#Q18. Increase funding of "CloudScale" by 50,000
university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["Systems Lab"]["research_projects"]["CloudScale"]["funding"] += 50000

# %%
#Q19. Add a new university to the system
university_system["universities"]["GTU_USA"] = {
    "location": "New York",
    "ranking": 1,
    "faculties": {}
}

# %%
#Q20. Add a new course under finance department
finance = university_system["universities"]["GTU_India"]["faculties"]["management"]["departments"]["finance"]["courses"]

finance["Financial Analytics"] = {
    "credits": 4,
    "students_enrolled": 60
}

# %%
#Q21. Find the project with the highest funding
highest_project = None
highest_funding = 0

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            if "labs" in department:
                for lab in department["labs"].values():
                    for project, details in lab["research_projects"].items():
                        if details["funding"] > highest_funding:
                            highest_funding = details["funding"]
                            highest_project = project

print(highest_project, highest_funding)
# Out:
# AutoNav 400000

# %%
#Q22. Find total funding across all universities
total_funding = 0

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            if "labs" in department:
                for lab in department["labs"].values():
                    for project in lab["research_projects"].values():
                        total_funding += project["funding"]

print(total_funding)
# Out:
# 1400000

# %%
#Q23. Find the university with the best ranking
best = min(
    university_system["universities"],
    key=lambda u: university_system["universities"][u]["ranking"]
)
print(best)
# Out:
# GTU_USA

# %%
#Q24. Print all completed projects
for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            if "labs" in department:
                for lab in department["labs"].values():
                    for project, details in lab["research_projects"].items():
                        if details["status"] == "completed":
                            print(project)
# Out:
# DeepVision
# RoboMind

# %%
#Q25. Count total number of researchers in GTU_India
count = 0

for faculty in university_system["universities"]["GTU_India"]["faculties"].values():
    for department in faculty["departments"].values():
        if "labs" in department:
            for lab in department["labs"].values():
                for project in lab["research_projects"].values():
                    count += len(project["researchers"])

print(count)
# Out:
# 8

# %%
#Q26. Find which lab has the maximum funding
lab_funding = {}

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            if "labs" in department:
                for lab_name, lab in department["labs"].items():
                    total = sum(p["funding"] for p in lab["research_projects"].values())
                    lab_funding[lab_name] = total

print(max(lab_funding, key=lab_funding.get))
# Out:
# AI Lab

# %%
#Q27. Print projects grouped by status (ongoing/completed)
grouped = {"ongoing": [], "completed": []}

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            if "labs" in department:
                for lab in department["labs"].values():
                    for project, details in lab["research_projects"].items():
                        grouped[details["status"]].append(project)

print(grouped)
# Out:
# {'ongoing': ['SmartAI', 'CloudScale', 'AutoNav'], 'completed': ['DeepVision', 'RoboMind']}

# %%
#Q28. Print all courses with more than 100 students enrolled
for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            if "courses" in department:
                for course, details in department["courses"].items():
                    if details["students_enrolled"] > 100:
                        print(course)
# Out:
# Data Structures

# %%
#Q29. Find total number of faculties in the entire system
total_faculties = sum(
    len(university["faculties"])
    for university in university_system["universities"].values()
)

print(total_faculties)
# Out:
# 3

# %%
#Q30. Write a function that searches for a project name and prints its full details
def search_project(project_name):
    for university in university_system["universities"].values():
        for faculty in university["faculties"].values():
            for department in faculty["departments"].values():
                if "labs" in department:
                    for lab in department["labs"].values():
                        if project_name in lab["research_projects"]:
                            print(lab["research_projects"][project_name])
                            return
    print("Project not found")

search_project("DeepVision")
# Out:
# {'funding': 250000, 'researchers': ['Arjun', 'Sneha'], 'status': 'completed'}
